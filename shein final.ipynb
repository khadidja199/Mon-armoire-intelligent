# %%
#POPUP

from tkinter import messagebox
import tkinter

fenetre = tkinter.Tk()
fenetre.title('my smart wardrobe')
l1 = tkinter.Label(text='what is your style ?')
style_entre1 = tkinter.Entry()
l2 = tkinter.Label(text='where are you from ?')
region_entre2 = tkinter.Entry()
bt1 = tkinter.Button(text='see the perfect outfit', command= onclick)
l1.pack()
style_entre1.pack()
l2.pack()
region_entre2.pack()
bt1.pack()
fenetre.geometry("500x200")
fenetre.lift()
fenetre.mainloop()
# Out:
# Taux d'humidite de 94%
# Prenez un parapluie
# 16.910000000000025
# 1

# %%
#Recuperation de la température

import requests
import json
import pandas as pd
import datetime

def temperature(ville):


    #récupère le temps actuel 
    url_weather = "http://api.openweathermap.org/data/2.5/weather?q="+ville+"&APPID=beb97c1ce62559bba4e81e28de8be095"
    #url="http://api.openweathermap.org/data/2.5/weather?q=Londres,uk&APPID=beb97c1ce62559bba4e81e28de8be095"

    r_weather = requests.get(url_weather)
    data = r_weather.json()

    #temperature moyenne
    t = data['main']['temp']  
    t = t-273.15
    #taux d'humidité
    humidite = data['main']['humidity']
    print("Taux d'humidite de {}".format(humidite) + "%")
    
    if 80 < humidite < 100:
        print("Prenez un parapluie")
    
    return t

# %%
#BOHEME
#Robe

import requests
from bs4 import BeautifulSoup
import os
import pandas as pd

def url_boheme_robe():
    url_boheme_robe = 'https://fr.shein.com/trends/New-in-Trends-sc-00654187.html?attr_values=Boho&ici=fr_tab01navbar02&scici=navbar_WomenHomePage~~tab01navbar02~~2~~itemPicking_00654187~~~~0&src_module=topcat&src_tab_page_id=page_home1665755591205&src_identifier=fc%3DWomen%60sc%3DAUTOMNE-HIVER%202022%60tc%3D0%60oc%3D0%60ps%3Dtab01navbar02%60jc%3DitemPicking_00654187&srctype=category&userpath=category-AUTOMNE-HIVER-2022&attr_ids=101_725&child_cat_id=1727'
    r = requests.get(url_boheme_robe)
    soup = BeautifulSoup(r.content, 'html.parser')
    for link in soup.find_all('img'):
        if link.get("data-src"):
            print(link.get("data-src"))
        
url_boheme_robe()
# Out:
# //img.ltwebstatic.com/images3_pi/2022/09/27/166424364701d137ceb1005e792062e4b4df0830b4_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/30/166450562750d25816b3e49286e811e8592ac7c6f7_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/04/08/1649397145269810a259a67ab0169e6d3b144163f9_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2021/04/08/16178478654d80080e30fce8f0d25c0905306f85f2_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2021/09/09/1631157707c6856deedf884ce42364ec3af657a036_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/21/1663732745d0b64c1d0ecadda34991ee5ff82e880e_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/04/28/1651126690d8fe9efc18e0da556c0925e588ac92dc_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2020/07/16/15948797188813da29ac1e33011909cf3c77015d2a_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/01/13/1642044484906f9d0f43dd3d7b55b828aca770e328_thumbnail_405x552.jpg
# ...

# %%
#BOHEME
#Jupe

import requests
from bs4 import BeautifulSoup
import os
import pandas as pd

def url_boheme_jupe():
    url_boheme_jupe = 'https://fr.shein.com/trends/New-in-Trends-sc-00654187.html?attr_values=Boho&ici=fr_tab01navbar02&scici=navbar_WomenHomePage~~tab01navbar02~~2~~itemPicking_00654187~~~~0&src_module=topcat&src_tab_page_id=page_home1665755591205&src_identifier=fc%3DWomen%60sc%3DAUTOMNE-HIVER%202022%60tc%3D0%60oc%3D0%60ps%3Dtab01navbar02%60jc%3DitemPicking_00654187&srctype=category&userpath=category-AUTOMNE-HIVER-2022&attr_ids=101_725&child_cat_id=1732'
    r = requests.get(url_boheme_jupe)
    soup = BeautifulSoup(r.content, 'html.parser')
    for link in soup.find_all('img'):
        if link.get("data-src"):
            print(link.get("data-src"))
        
url

    soup = BeautifulSoup(r.content, 'html.parser')
    for link in soup.find_all('img'):
        if link.get("data-src"):
            print(link.get("data-src"))
        
url_elegant_pantalon()
# Out:
# //img.ltwebstatic.com/images3_pi/2021/09/30/1632986072ea7707c1f8af9a5cd4b64a32a0d80d8d_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/01/1662015239b2f135d8c960451d50f61b8cb5928242_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2021/10/11/16339248662e298454a7a95b54ced11d1b0ff5aaec_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/10/08/1665197875387943709b90e128af4f3cff06193e9e_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2021/11/12/1636706637dc1b262decfa7294d59288f240212e7f_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/16/16633166374232450d4444be675efbcd5e8dce4b8e_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/06/1662436673894855374345aec030bc1cfc7e4805e9_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2021/11/16/16370403790ef9e85e54f86a987ea2bd23bd9e0830_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/11/1662880499304df30735677696cd21b3806a586981_thumbnail_405x552.jpg
# ...

# %%
#Elegant
#Robe

import requests
from bs4 import BeautifulSoup
import os
import pandas as pd

def url_elegant_robe():
    url_elegant_robe = 'https://fr.shein.com/Women-Clothing-c-2030.html?attr_values=Elegant&ici=fr_tab01navbar03&scici=navbar_WomenHomePage~~tab01navbar03~~3~~real_2030~~~~0&src_module=topcat&src_tab_page_id=page_real_class1665775257714&src_identifier=fc%3DWomen%60sc%3DV%C3%8ATEMENTS%60tc%3D0%60oc%3D0%60ps%3Dtab01navbar03%60jc%3Dreal_2030&srctype=category&userpath=category-V%C3%8ATEMENTS&attr_ids=101_257&child_cat_id=1727'
    r = requests.get(url_elegant_robe)
    soup = BeautifulSoup(r.content, 'html.parser')
    for link in soup.find_all('img'):
        if link.get("data-src"):
            print(link.get("data-src"))
        
url_elegant_robe()
# Out:
# //img.ltwebstatic.com/images3_pi/2022/09/21/1663728632fee3694f8c4ec6eb1bf08433e5c748f8_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/27/1664272445648711d15f79395338ed86e6f8735ea4_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/20/1663680524760401b3b1f5d4cf5519be54095b66ea_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/15/1663209555ad014c764ff5b1fa7469136ed1b863b7_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/01/1662002611f65e5ca1e669d9c26efa3b9b8c02aad8_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/27/1664247458cb3a2d63542ae5221758798bb88dbea3_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/26/1664172783e0aaf8b9d9496624c3b5e5d451f91053_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2021/12/21/1640058551fdd9f6a12156749704262f2c79c4c0cb_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/09/16627185191a7d671653f05675c698eceb06554334_thumbnail_405x552.jpg
# ...

# %%
#Elegant
#Tshirt

import requests
from bs4 import BeautifulSoup
import os
import pandas as pd

def url_elegant_tshirt():
    url_elegant_tshirt = 'https://fr.shein.com/Women-Clothing-c-2030.html?attr_values=Elegant&ici=fr_tab01navbar03&scici=navbar_WomenHomePage~~tab01navbar03~~3~~real_2030~~~~0&src_module=topcat&src_tab_page_id=page_real_class1665775257714&src_identifier=fc%3DWomen%60sc%3DV%C3%8ATEMENTS%60tc%3D0%60oc%3D0%60ps%3Dtab01navbar03%60jc%3Dreal_2030&srctype=category&userpath=category-V%C3%8ATEMENTS&attr_ids=101_257&child_cat_id=1738'
    r = requests.get(url_elegant_tshirt)
    soup = BeautifulSoup(r.content, 'html.parser')
    for link in soup.find_all('img'):
        if link.get("data-src"):
            print(link.get("data-src"))
        
url_elegant_tshirt()
# Out:
# //img.ltwebstatic.com/images3_pi/2022/07/26/1658802030f79f1495856c8e33d2b046cba5d482d0_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images2_pi/2018/08/10/15338860921884607937_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/10/10/1665394733edf22543c0d204b4b347b03a467c1ed0_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/26/1664157661c93b2486214c887f4afad1864caa376a_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/08/12/16602336397298547641bd91cef738faf996721cc7_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/16/166331918278824c43cf14c00a4a56391d4089bd2e_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2021/08/25/16298732254af0c56d10bfbb36c9ad268f3cae0614_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2021/09/17/1631860415b43cfda7c21df65458d126ba899fc650_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2021/12/02/1638414166d008ee4734ac159379c782dafa64157a_thumbnail_405x552.jpg
# ...

# %%
#Elegant
#Veste

import requests
from bs4 import BeautifulSoup
import os
import pandas as pd

def url_elegant_veste():
    url_elegant_veste = 'https://fr.shein.com/Women-Clothing-c-2030.html?attr_values=Elegant&ici=fr_tab01navbar03&scici=navbar_WomenHomePage~~tab01navbar03~~3~~real_2030~~~~0&src_module=topcat&src_tab_page_id=page_real_class1665775257714&src_identifier=fc%3DWomen%60sc%3DV%C3%8ATEMENTS%60tc%3D0%60oc%3D0%60ps%3Dtab01navbar03%60jc%3Dreal_2030&srctype=category&userpath=category-V%C3%8ATEMENTS&attr_ids=101_257&child_cat_id=1776'
    r = requests.get(url_elegant_veste)
    soup = BeautifulSoup(r.content, 'html.parser')
    for link in soup.find_all('img'):
        if link.get("data-src"):
            print(link.get("data-src"))
        
url_elegant_veste()
# Out:
# //img.ltwebstatic.com/images3_pi/2022/08/29/1661739066da4f111c65a809451a3ecb314e8ac474_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/08/30/1661853730b6df16c53d72ff9a2051edbc7d620a3f_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/04/16622610631c53534ab3228b72db13d5724f55b1e3_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2021/07/19/1626697478d86cd68486045f4f2e391840785920b4_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/07/07/165715662035348832960c922f06e530c8a70d343e_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/08/09/1660013618dcadd3956b05ff9e9de968618d2b81aa_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/08/11/1660207072c2b3a0ba7b8d77ab77187bb5da84db88_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/07/01/1656639476ce50d772be91c2eb0fdcceb7838a755a_thumbnail_405x552.jpg
# //img.ltwebstatic.com/images3_pi/2022/09/03/1662134445ffeb8319d92528be16e989e1a612e850_thumbnail_405x552.jpg
# ...

# %%
import os
import glob
path = os.getcwd()

styles = ["casual", "elegant", "boheme", "sexy"] 
dict_style = {"casual":1, "elegant":2, "boheme":3, "sexy":4}

data_final = pd.DataFrame()
for style in styles:
    xlfiles = glob.glob(os.path.join(os.path.join(path, style), "*.xlsx"))
    for i, xlfile in enumerate(xlfiles, 1):
        data = pd.read_excel(xlfile)
        tag = dict_style[style] * 10+i
        list_tag = [tag for i in range (len(data))]
        data["target"] = list_tag
        frames = [data_final, data]
        data_final = pd.concat(frames)

# %%
len(data_final)
# Out:
# 2888

# %%
#si temp comprise entre 0 et 5 proposer manteaux 
# temp comprise entre 5 et 15 proposer veste
#si temp comprise entre 0 et 10 proposer pull + pantalon
#si temp comprise entre 10 et 20 proposer tshirt + pantalon
#si temp + de 20 proposer robe ou tshirt + jupe

# %%
import random
import numpy as np

def get_clothes(temp, data, style):
    dict_type = {
        (0,5): 2,
        (5,15):7,
        (0,10): (3,4),
        (10,20): (6,3),
        (20,50): [5, (6,1)]
                }
    list_choix = []
    for temp_compare, value in dict_type.items():
        if temp >= temp_compare[0] and temp < temp_compare[1]:
            if temp > 20 :
                if random.uniform(0,1) < 0.5:
                    list_choix.append(value[0])
                else:
                    list_choix.append(value[1][0])
                    list_choix.append(value[1][1])
            else:
                if type(value) == int:
                    list_choix.append(value)
                else:
                    list_choix.append(value[0])
                    list_choix.append(value[1])
    
    tags = [style * 10 + choix for choix in list_choix]
    list_image = []
    for tag in tags:
        data_tag = data[data["target"] == tag]
        n_article = np.random.randint(0, len(data_tag))
        list_image.append(data_tag.iloc[n_article]["URLS"])

    return list_image

# %%
#Convertir url image en image

from PIL import Image
from io import BytesIO

def get_image_from_url(url):
    reponse = requests.get('http:'+ url,stream = True)
    return Image.open( BytesIO(reponse.content))

# %%
#Fonction globale pour le POPUP

def onclick():
    style = style_entre1.get()
    region = region_entre2.get()
    temp = temperature(region)
    print(temp)
    if style.lower() in styles:
        style_ = dict_style[style.lower()]
        print(style_)
        list_url = get_clothes(temp, data_final, style_)
        for url in list_url:
            get_image_from_url(url).show()
    else:
        messagebox.showinfo("style", "please choose style from : {}".format(styles))
